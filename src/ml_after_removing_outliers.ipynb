# %%
import pandas as pd

df = pd.read_parquet('../data/pivot_data_hourly_cleaned.parquet')

# %%
from sklearn.model_selection import train_test_split


df = df.dropna()
X = df.shift(1).iloc[1:]  # previous readings (inputs)
Y = df.iloc[1:]           # current readings (targets)

print(X.head())
print(Y.head())

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, shuffle=False)
# Out:
# MeasurementName      SSA 3 Lysimeter UMP 120cm %  SSA 3 Lysimeter UMP 30cm %  \
# MeasureDate
# 2013-07-01 01:00:00                    32.700000                   25.170000
# 2013-07-01 02:00:00                    32.680000                   25.160000
# 2013-07-01 03:00:00                    32.625000                   25.165000
# 2013-07-01 04:00:00                    32.625000                   25.067501
# 2013-07-01 05:00:00                    32.633334                   25.030001
#
# MeasurementName      SSA 3 Lysimeter UMP 75cm %  SSA 3 Lysimeter battery V  \
# MeasureDate
# 2013-07-01 01:00:00                   33.691999                     12.706
# 2013-07-01 02:00:00                   33.695000                     12.685
# 2013-07-01 03:00:00                   33.732499                     12.670
# 2013-07-01 04:00:00                   33.779999                     12.655
# 2013-07-01 05:00:00                   33.779999                     12.660
#
# MeasurementName      SSA 3 Lysimeter ec 120cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                          0.1060
# 2013-07-01 02:00:00                          0.1100
# 2013-07-01 03:00:00                          0.1075
# 2013-07-01 04:00:00                          0.1050
# 2013-07-01 05:00:00                          0.1100
#
# MeasurementName      SSA 3 Lysimeter ec 30cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                         0.1260
# 2013-07-01 02:00:00                         0.1200
# 2013-07-01 03:00:00                         0.1175
# 2013-07-01 04:00:00                         0.1300
# 2013-07-01 05:00:00                         0.1300
#
# MeasurementName      SSA 3 Lysimeter ec 75cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                       0.132000
# 2013-07-01 02:00:00                       0.130000
# 2013-07-01 03:00:00                       0.135000
# 2013-07-01 04:00:00                       0.135000
# 2013-07-01 05:00:00                       0.082622
#
# MeasurementName      SSA 3 Lysimeter scale (1) kg  \
# MeasureDate
# 2013-07-01 01:00:00                   2845.463965
# 2013-07-01 02:00:00                   2845.454956
# 2013-07-01 03:00:00                   2845.447449
# 2013-07-01 04:00:00                   2845.439941
# 2013-07-01 05:00:00                   2845.423258
#
# MeasurementName      SSA 3 Lysimeter temperature 120cm degC  \
# MeasureDate
# 2013-07-01 01:00:00                               16.708000
# 2013-07-01 02:00:00                               16.675000
# 2013-07-01 03:00:00                               16.665000
# 2013-07-01 04:00:00                               16.640000
# 2013-07-01 05:00:00                               16.593334
#
# MeasurementName      SSA 3 Lysimeter temperature 30cm degC  ...  \
# MeasureDate                                                 ...
# 2013-07-01 01:00:00                              18.398000  ...
# 2013-07-01 02:00:00                              18.320000  ...
# 2013-07-01 03:00:00                              18.200000  ...
# 2013-07-01 04:00:00                              18.045000  ...
# 2013-07-01 05:00:00                              17.906667  ...
#
# MeasurementName      Weather Station UMP (1) temperature degC  \
# MeasureDate
# 2013-07-01 01:00:00                                 18.758000
# 2013-07-01 02:00:00                                 18.653334
# 2013-07-01 03:00:00                                 18.530000
# 2013-07-01 04:00:00                                 18.372000
# 2013-07-01 05:00:00                                 18.213333
#
# MeasurementName      Weather Station air pressure hPa  \
# MeasureDate
# 2013-07-01 01:00:00                       1018.731994
# 2013-07-01 02:00:00                       1018.826660
# 2013-07-01 03:00:00                       1018.590011
# 2013-07-01 04:00:00                       1018.610010
# 2013-07-01 05:00:00                       1018.843343
#
# MeasurementName      Weather Station air temperature degC  \
# MeasureDate
# 2013-07-01 01:00:00                              7.496000
# 2013-07-01 02:00:00                              7.093333
# 2013-07-01 03:00:00                              7.517500
# 2013-07-01 04:00:00                              7.048000
# 2013-07-01 05:00:00                              8.376667
#
# MeasurementName      Weather Station battery V  Weather Station humidity %  \
# MeasureDate
# 2013-07-01 01:00:00                    12.9060                   89.694000
# 2013-07-01 02:00:00                    12.8700                   91.213333
# 2013-07-01 03:00:00                    12.8525                   90.597499
# 2013-07-01 04:00:00                    12.8400                   93.504001
# 2013-07-01 05:00:00                    12.8300                   93.353332
#
# MeasurementName      Weather Station precipitation mm  \
# MeasureDate
# 2013-07-01 01:00:00                               0.0
# 2013-07-01 02:00:00                               0.0
# 2013-07-01 03:00:00                               0.0
# 2013-07-01 04:00:00                               0.0
# 2013-07-01 05:00:00                               0.0
#
# MeasurementName      Weather Station radiation W/qm  \
# MeasureDate
# 2013-07-01 01:00:00                         -5.4000
# 2013-07-01 02:00:00                         -5.0700
# 2013-07-01 03:00:00                         -4.9025
# 2013-07-01 04:00:00                         -2.9640
# 2013-07-01 05:00:00                         17.5800
#
# MeasurementName      Weather Station temperature (5+) degC  \
# MeasureDate
# 2013-07-01 01:00:00                               8.728000
# 2013-07-01 02:00:00                               8.453333
# 2013-07-01 03:00:00                               8.315000
# 2013-07-01 04:00:00                               8.216000
# 2013-07-01 05:00:00                               9.643333
#
# MeasurementName      Weather Station wind direction deg  \
# MeasureDate
# 2013-07-01 01:00:00                          193.352000
# 2013-07-01 02:00:00                          211.603336
# 2013-07-01 03:00:00                          300.357506
# 2013-07-01 04:00:00                           45.595999
# 2013-07-01 05:00:00                           49.363333
#
# MeasurementName      Weather Station wind speed m/s
# MeasureDate
# 2013-07-01 01:00:00                        0.052000
# 2013-07-01 02:00:00                        0.253333
# 2013-07-01 03:00:00                        0.447500
# 2013-07-01 04:00:00                        0.006000
# 2013-07-01 05:00:00                        0.096667
#
# [5 rows x 75 columns]
# MeasurementName      SSA 3 Lysimeter UMP 120cm %  SSA 3 Lysimeter UMP 30cm %  \
# MeasureDate
# 2013-07-01 01:00:00                    32.680000                   25.160000
# 2013-07-01 02:00:00                    32.625000                   25.165000
# 2013-07-01 03:00:00                    32.625000                   25.067501
# 2013-07-01 04:00:00                    32.633334                   25.030001
# 2013-07-01 05:00:00                    32.630000                   25.040001
#
# MeasurementName      SSA 3 Lysimeter UMP 75cm %  SSA 3 Lysimeter battery V  \
# MeasureDate
# 2013-07-01 01:00:00                   33.695000                  12.685000
# 2013-07-01 02:00:00                   33.732499                  12.670000
# 2013-07-01 03:00:00                   33.779999                  12.655000
# 2013-07-01 04:00:00                   33.779999                  12.660000
# 2013-07-01 05:00:00                   33.773333                  12.693333
#
# MeasurementName      SSA 3 Lysimeter ec 120cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                        0.110000
# 2013-07-01 02:00:00                        0.107500
# 2013-07-01 03:00:00                        0.105000
# 2013-07-01 04:00:00                        0.110000
# 2013-07-01 05:00:00                        0.106667
#
# MeasurementName      SSA 3 Lysimeter ec 30cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                         0.1200
# 2013-07-01 02:00:00                         0.1175
# 2013-07-01 03:00:00                         0.1300
# 2013-07-01 04:00:00                         0.1300
# 2013-07-01 05:00:00                         0.1000
#
# MeasurementName      SSA 3 Lysimeter ec 75cm mS/cm  \
# MeasureDate
# 2013-07-01 01:00:00                       0.130000
# 2013-07-01 02:00:00                       0.135000
# 2013-07-01 03:00:00                       0.135000
# 2013-07-01 04:00:00                       0.082622
# 2013-07-01 05:00:00                       0.126667
#
# MeasurementName      SSA 3 Lysimeter scale (1) kg  \
# MeasureDate
# 2013-07-01 01:00:00                   2845.454956
# 2013-07-01 02:00:00                   2845.447449
# 2013-07-01 03:00:00                   2845.439941
# 2013-07-01 04:00:00                   2845.423258
# 2013-07-01 05:00:00                   2845.376628
#
# MeasurementName      SSA 3 Lysimeter temperature 120cm degC  \
# MeasureDate
# 2013-07-01 01:00:00                               16.675000
# 2013-07-01 02:00:00                               16.665000
# 2013-07-01 03:00:00                               16.640000
# 2013-07-01 04:00:00                               16.593334
# 2013-07-01 05:00:00                               16.586667
#
# MeasurementName      SSA 3 Lysimeter temperature 30cm degC  ...  \
# MeasureDate                                                 ...
# 2013-07-01 01:00:00                              18.320000  ...
# 2013-07-01 02:00:00                              18.200000  ...
# 2013-07-01 03:00:00                              18.045000  ...
# 2013-07-01 04:00:00                              17.906667  ...
# 2013-07-01 05:00:00                              17.803334  ...
#
# MeasurementName      Weather Station UMP (1) temperature degC  \
# MeasureDate
# 2013-07-01 01:00:00                                 18.653334
# 2013-07-01 02:00:00                                 18.530000
# 2013-07-01 03:00:00                                 18.372000
# 2013-07-01 04:00:00                                 18.213333
# 2013-07-01 05:00:00                                 18.062500
#
# MeasurementName      Weather Station air pressure hPa  \
# MeasureDate
# 2013-07-01 01:00:00                       1018.826660
# 2013-07-01 02:00:00                       1018.590011
# 2013-07-01 03:00:00                       1018.610010
# 2013-07-01 04:00:00                       1018.843343
# 2013-07-01 05:00:00                       1019.105011
#
# MeasurementName      Weather Station air temperature degC  \
# MeasureDate
# 2013-07-01 01:00:00                              7.093333
# 2013-07-01 02:00:00                              7.517500
# 2013-07-01 03:00:00                              7.048000
# 2013-07-01 04:00:00                              8.376667
# 2013-07-01 05:00:00                              9.165000
#
# MeasurementName      Weather Station battery V  Weather Station humidity %  \
# MeasureDate
# 2013-07-01 01:00:00                    12.8700                   91.213333
# 2013-07-01 02:00:00                    12.8525                   90.597499
# 2013-07-01 03:00:00                    12.8400                   93.504001
# 2013-07-01 04:00:00                    12.8300                   93.353332
# 2013-07-01 05:00:00                    12.9375                   91.302502
#
# MeasurementName      Weather Station precipitation mm  \
# MeasureDate
# 2013-07-01 01:00:00                               0.0
# 2013-07-01 02:00:00                               0.0
# 2013-07-01 03:00:00                               0.0
# 2013-07-01 04:00:00                               0.0
# 2013-07-01 05:00:00                               0.0
#
# MeasurementName      Weather Station radiation W/qm  \
# MeasureDate
# 2013-07-01 01:00:00                       -5.070000
# 2013-07-01 02:00:00                       -4.902500
# 2013-07-01 03:00:00                       -2.964000
# 2013-07-01 04:00:00                       17.580000
# 2013-07-01 05:00:00                       69.860002
#
# MeasurementName      Weather Station temperature (5+) degC  \
# MeasureDate
# 2013-07-01 01:00:00                               8.453333
# 2013-07-01 02:00:00                               8.315000
# 2013-07-01 03:00:00                               8.216000
# 2013-07-01 04:00:00                               9.643333
# 2013-07-01 05:00:00                              10.360000
#
# MeasurementName      Weather Station wind direction deg  \
# MeasureDate
# 2013-07-01 01:00:00                          211.603336
# 2013-07-01 02:00:00                          300.357506
# 2013-07-01 03:00:00                           45.595999
# 2013-07-01 04:00:00                           49.363333
# 2013-07-01 05:00:00                          133.925001
#
# MeasurementName      Weather Station wind speed m/s
# MeasureDate
# 2013-07-01 01:00:00                        0.253333
# 2013-07-01 02:00:00                        0.447500
# 2013-07-01 03:00:00                        0.006000
# 2013-07-01 04:00:00                        0.096667
# 2013-07-01 05:00:00                        0.047500
#
# [5 rows x 75 columns]

# %%
from lightgbm import LGBMRegressor
from tqdm import tqdm


models = {}

# Training loop
for i, col in enumerate(tqdm(Y_train.columns, desc="Training models")):
    var = Y_train[col].var()
    if var <= 100:
        params = {'n_estimators': 100, 'learning_rate': 0.02, 'max_depth': 7, "num_leaves": 31, 'min_child_samples': 20}
    elif var >= 100 and var < 500:
        params = {'n_estimators': 175, 'learning_rate': 0.03, 'max_depth': 12, "num_leaves": 63, 'min_child_samples': 15}
    else:
        params = {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 25, "num_leaves": 127, 'min_child_samples': 10}
    model = LGBMRegressor(
        n_estimators=params['n_estimators'],
        learning_rate=params['learning_rate'],
        max_depth=params['max_depth'],
        n_jobs=-1,
        force_col_wise=True,
        num_leaves=params["num_leaves"],
        min_child_samples=params['min_child_samples'],
        
    )
    
    model.fit(
        X_train,
        Y_train[col].values,
        eval_set=[(X_test, Y_test[col].values)],
        eval_metric='rmse',
    )
    
    models[col] = model
# Out:
# Training models:   0%|          | 0/75 [00:00<?, ?it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 30.576620
# Training models:   1%|▏         | 1/75 [00:00<00:50,  1.48it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 33.965698
# Training models:   3%|▎         | 2/75 [00:01<00:43,  1.67it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 29.175542
# Training models:   4%|▍         | 3/75 [00:01<00:42,  1.71it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 12.676436
# Training models:   5%|▌         | 4/75 [00:02<00:40,  1.76it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.074126
# Training models:   7%|▋         | 5/75 [00:02<00:37,  1.84it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.129168
# Training models:   8%|▊         | 6/75 [00:03<00:36,  1.87it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 0.086105
# Training models:   9%|▉         | 7/75 [00:03<00:36,  1.87it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 2883.257007
# Training models:  11%|█         | 8/75 [00:07<01:33,  1.39s/it]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 10.325040
# Training models:  12%|█▏        | 9/75 [00:07<01:16,  1.15s/it]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 11.504145
# Training models:  13%|█▎        | 10/75 [00:08<01:03,  1.02it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 11.408549
# Training models:  15%|█▍        | 11/75 [00:08<00:55,  1.15it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 5.851934
# Training models:  16%|█▌        | 12/75 [00:09<00:49,  1.28it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score -0.045622
# Training models:  17%|█▋        | 13/75 [00:10<00:43,  1.44it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 7.492568
# Training models:  19%|█▊        | 14/75 [00:10<00:39,  1.56it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 3.445667
# Training models:  20%|██        | 15/75 [00:11<00:35,  1.67it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 2.832574
# Training models:  21%|██▏       | 16/75 [00:11<00:33,  1.78it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 7.478921
# Training models:  23%|██▎       | 17/75 [00:12<00:31,  1.86it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 37.580310
# Training models:  24%|██▍       | 18/75 [00:12<00:31,  1.83it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 33.834079
# Training models:  25%|██▌       | 19/75 [00:13<00:31,  1.75it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 33.915625
# Training models:  27%|██▋       | 20/75 [00:13<00:33,  1.64it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 33.432576
# Training models:  28%|██▊       | 21/75 [00:14<00:31,  1.71it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 37.480630
# Training models:  29%|██▉       | 22/75 [00:15<00:32,  1.64it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 31.055412
# Training models:  31%|███       | 23/75 [00:15<00:32,  1.62it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 34.561968
# Training models:  32%|███▏      | 24/75 [00:16<00:30,  1.68it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 37.415769
# Training models:  33%|███▎      | 25/75 [00:16<00:30,  1.65it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 30.432722
# Training models:  35%|███▍      | 26/75 [00:17<00:29,  1.66it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 12.374395
# Training models:  37%|███▋      | 28/75 [00:18<00:22,  2.06it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Training models:  39%|███▊      | 29/75 [00:18<00:19,  2.40it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Training models:  40%|████      | 30/75 [00:18<00:16,  2.74it/s]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 55.769265
# Training models:  96%|█████████▌| 72/75 [00:58<00:04,  1.46s/it]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 11.659192
# Training models:  97%|█████████▋| 73/75 [00:58<00:02,  1.19s/it]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 171.713433
# Training models:  99%|█████████▊| 74/75 [01:02<00:01,  1.87s/it]
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Total Bins 16269
# [LightGBM] [Info] Number of data points in the train set: 65016, number of used features: 70
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 1.412384
# Training models: 100%|██████████| 75/75 [01:02<00:00,  1.19it/s]

# %%
from sklearn.metrics import root_mean_squared_error
import numpy as np
import pandas as pd


Y_pred = np.column_stack([models[col].predict(X_test) for col in Y_train.columns])


Y_pred_df = pd.DataFrame(Y_pred, columns=Y_test.columns, index=Y_test.index)

# RMSE for every column
rmse_scores = {col: root_mean_squared_error(Y_test[col], Y_pred_df[col]) 
               for col in Y_test.columns}

# RMSE
for col, score in rmse_scores.items():
    print(f"{col}: RMSE = {score:.4f}")
# Out:
# SSA 3 Lysimeter UMP 120cm %: RMSE = 2.6093
# SSA 3 Lysimeter UMP 30cm %: RMSE = 1.1889
# SSA 3 Lysimeter UMP 75cm %: RMSE = 1.0820
# SSA 3 Lysimeter battery V: RMSE = 0.1402
# SSA 3 Lysimeter ec 120cm mS/cm: RMSE = 0.0080
# SSA 3 Lysimeter ec 30cm mS/cm: RMSE = 0.0048
# SSA 3 Lysimeter ec 75cm mS/cm: RMSE = 0.0049
# SSA 3 Lysimeter scale (1) kg: RMSE = 29.1933
# SSA 3 Lysimeter temperature 120cm degC: RMSE = 0.6863
# SSA 3 Lysimeter temperature 30cm degC: RMSE = 0.9198
# SSA 3 Lysimeter temperature 75cm degC: RMSE = 0.7741
# SSA 3 Lysimeter tension 120cm kPa: RMSE = 0.7384
# SSA 3 Lysimeter tension 30cm kPa: RMSE = 0.2809
# SSA 3 Lysimeter tension 75cm kPa: RMSE = 1.2042
# SSA 3 Lysimeter vacuum 120cm kPa: RMSE = 0.1279
# SSA 3 Lysimeter vacuum 30cm kPa: RMSE = 0.2486
# SSA 3 Lysimeter vacuum 75cm kPa: RMSE = 1.1141
# SSA 4 Schacht UMP (1) 120cm %: RMSE = 5.7850
# SSA 4 Schacht UMP (1) 30cm %: RMSE = 0.5216
# SSA 4 Schacht UMP (1) 75cm %: RMSE = 1.5617
# SSA 4 Schacht UMP (2) 120cm %: RMSE = 10.4707
# SSA 4 Schacht UMP (2) 30cm %: RMSE = 1.0200
# SSA 4 Schacht UMP (2) 75cm %: RMSE = 1.8632
# SSA 4 Schacht UMP (3) 120cm %: RMSE = 11.9850
# SSA 4 Schacht UMP (3) 30cm %: RMSE = 1.1266
# SSA 4 Schacht UMP (3) 75cm %: RMSE = 1.2407
# SSA 4 Schacht battery V: RMSE = 0.1571
# SSA 4 Schacht discharge (1) l: RMSE = 0.0000
# SSA 4 Schacht discharge (2) l: RMSE = 0.0000
# SSA 4 Schacht discharge (3) l: RMSE = 0.0000
# SSA 4 Schacht ec (1) 120cm mS/cm: RMSE = 0.0579
# SSA 4 Schacht ec (1) 30cm mS/cm: RMSE = 0.0047
# SSA 4 Schacht ec (1) 75cm mS/cm: RMSE = 0.0090
# SSA 4 Schacht ec (2) 120cm mS/cm: RMSE = 0.0085
# SSA 4 Schacht ec (2) 30cm mS/cm: RMSE = 0.0121
# SSA 4 Schacht ec (2) 75cm mS/cm: RMSE = 0.0064
# SSA 4 Schacht ec (3) 120cm mS/cm: RMSE = 0.0116
# SSA 4 Schacht ec (3) 30cm mS/cm: RMSE = 0.0037
# SSA 4 Schacht ec (3) 75cm mS/cm: RMSE = 0.0064
# SSA 4 Schacht temperature (1) 120cm degC: RMSE = 2.1621
# SSA 4 Schacht temperature (1) 30cm degC: RMSE = 1.0630
# SSA 4 Schacht temperature (1) 75cm degC: RMSE = 0.7831
# SSA 4 Schacht temperature (2) 120cm degC: RMSE = 0.6926
# SSA 4 Schacht temperature (2) 30cm degC: RMSE = 0.8915
# SSA 4 Schacht temperature (2) 75cm degC: RMSE = 0.8363
# SSA 4 Schacht temperature (3) 120cm degC: RMSE = 0.7804
# SSA 4 Schacht temperature (3) 30cm degC: RMSE = 1.2187
# SSA 4 Schacht temperature (3) 75cm degC: RMSE = 0.7977
# SSA 4 Schacht vacuum 120cm kPa: RMSE = 4.8708
# SSA 4 Schacht vacuum 140cm kPa: RMSE = 2.1550
# SSA 4 Schacht vacuum 30cm kPa: RMSE = 6.0737
# SSA 4 Schacht vacuum 75cm kPa: RMSE = 5.6411
# URB Lysimeter discharge (1) l: RMSE = 0.0000
# URB Lysimeter inside temperature degC: RMSE = 0.6801
# URB Lysimeter inside tension kPa: RMSE = 0.6410
# URB Lysimeter level cm: RMSE = 1.1635
# URB Lysimeter level reference cm: RMSE = 0.0987
# URB Lysimeter outside temperature degC: RMSE = 0.6758
# URB Lysimeter outside tension kPa: RMSE = 1.1639
# URB Lysimeter outside tension reference kPa: RMSE = 4.8726
# URB Lysimeter percolation pump mV: RMSE = 1.6642
# URB Lysimeter temperature control mV: RMSE = 1.5017
# URB Lysimeter vacuum kPa: RMSE = 0.1822
# Weather Station UMP (1) %: RMSE = 0.8862
# Weather Station UMP (1) ec mS/cm: RMSE = 0.0056
# Weather Station UMP (1) temperature degC: RMSE = 0.5911
# Weather Station air pressure hPa: RMSE = 1.2660
# Weather Station air temperature degC: RMSE = 1.6321
# Weather Station battery V: RMSE = 0.1885
# Weather Station humidity %: RMSE = 3.8959
# Weather Station precipitation mm: RMSE = 0.0000
# Weather Station radiation W/qm: RMSE = 40.5983
# Weather Station temperature (5+) degC: RMSE = 1.8928
# Weather Station wind direction deg: RMSE = 77.1859
# Weather Station wind speed m/s: RMSE = 0.6057

# %%
import matplotlib.pyplot as plt

col = 'SSA 3 Lysimeter UMP 120cm %'

plt.figure(figsize=(12, 6))

# Plot actual values as a line
plt.plot(Y_test.index, Y_test[col], color='blue', label='Actual', linewidth=2)

# Plot predicted values as a line (directly from models)
Y_pred_col = np.array([models[col].predict(X_test) for col in [col]]).flatten()
plt.plot(Y_test.index, Y_pred_col, color='orange', linestyle='--', label='Predicted', linewidth=2)

plt.xlabel('Index', fontsize=12)
plt.ylabel(col, fontsize=12)
plt.title(f'{col} Prediction vs Actual', fontsize=14)
plt.legend(fontsize=12)

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
import pandas as pd
import numpy as np

# Make predictions for all columns
Y_pred = np.column_stack([models[col].predict(X_test) for col in Y_train.columns])
Y_pred_df = pd.DataFrame(Y_pred, columns=Y_test.columns, index=Y_test.index)

# Compute metrics per column
metrics = {}
for col in Y_test.columns:
    rmse = root_mean_squared_error(Y_test[col], Y_pred_df[col])  # RMSE
    mae = mean_absolute_error(Y_test[col], Y_pred_df[col])       # MAE
    r2 = r2_score(Y_test[col], Y_pred_df[col])                   # R²
    metrics[col] = {"RMSE": rmse, "MAE": mae, "R2": r2}

# Display metrics
for col, m in metrics.items():
    print(f"{col}: RMSE = {m['RMSE']:.4f}, MAE = {m['MAE']:.4f}, R² = {m['R2']:.4f}")
# Out:
# SSA 3 Lysimeter UMP 120cm %: RMSE = 2.6093, MAE = 2.4461, R² = 0.6103
# SSA 3 Lysimeter UMP 30cm %: RMSE = 1.1889, MAE = 1.1098, R² = 0.9717
# SSA 3 Lysimeter UMP 75cm %: RMSE = 1.0820, MAE = 0.9532, R² = 0.9211
# SSA 3 Lysimeter battery V: RMSE = 0.1402, MAE = 0.1172, R² = 0.9302
# SSA 3 Lysimeter ec 120cm mS/cm: RMSE = 0.0080, MAE = 0.0066, R² = 0.7337
# SSA 3 Lysimeter ec 30cm mS/cm: RMSE = 0.0048, MAE = 0.0033, R² = 0.9143
# SSA 3 Lysimeter ec 75cm mS/cm: RMSE = 0.0049, MAE = 0.0033, R² = 0.8891
# SSA 3 Lysimeter scale (1) kg: RMSE = 29.1933, MAE = 20.1304, R² = 0.7343
# SSA 3 Lysimeter temperature 120cm degC: RMSE = 0.6863, MAE = 0.5991, R² = 0.9798
# SSA 3 Lysimeter temperature 30cm degC: RMSE = 0.9198, MAE = 0.7812, R² = 0.9801
# SSA 3 Lysimeter temperature 75cm degC: RMSE = 0.7741, MAE = 0.6693, R² = 0.9804
# SSA 3 Lysimeter tension 120cm kPa: RMSE = 0.7384, MAE = 0.7281, R² = -0.8521
# SSA 3 Lysimeter tension 30cm kPa: RMSE = 0.2809, MAE = 0.1783, R² = 0.8836
# SSA 3 Lysimeter tension 75cm kPa: RMSE = 1.2042, MAE = 1.0865, R² = 0.6257
# SSA 3 Lysimeter vacuum 120cm kPa: RMSE = 0.1279, MAE = 0.1122, R² = -0.2030
# SSA 3 Lysimeter vacuum 30cm kPa: RMSE = 0.2486, MAE = 0.1980, R² = 0.5922
# SSA 3 Lysimeter vacuum 75cm kPa: RMSE = 1.1141, MAE = 0.9222, R² = -1.1123
# SSA 4 Schacht UMP (1) 120cm %: RMSE = 5.7850, MAE = 5.2713, R² = 0.7631
# SSA 4 Schacht UMP (1) 30cm %: RMSE = 0.5216, MAE = 0.4218, R² = 0.9882
# SSA 4 Schacht UMP (1) 75cm %: RMSE = 1.5617, MAE = 1.0647, R² = 0.9586
# SSA 4 Schacht UMP (2) 120cm %: RMSE = 10.4707, MAE = 8.0890, R² = -0.2503
# SSA 4 Schacht UMP (2) 30cm %: RMSE = 1.0200, MAE = 0.7118, R² = 0.9285
# SSA 4 Schacht UMP (2) 75cm %: RMSE = 1.8632, MAE = 1.3893, R² = 0.9307
# SSA 4 Schacht UMP (3) 120cm %: RMSE = 11.9850, MAE = 9.4239, R² = -0.6584
# SSA 4 Schacht UMP (3) 30cm %: RMSE = 1.1266, MAE = 0.6689, R² = 0.9497
# SSA 4 Schacht UMP (3) 75cm %: RMSE = 1.2407, MAE = 0.9393, R² = 0.9544
# SSA 4 Schacht battery V: RMSE = 0.1571, MAE = 0.0978, R² = 0.8876
# SSA 4 Schacht discharge (1) l: RMSE = 0.0000, MAE = 0.0000, R² = 1.0000
# SSA 4 Schacht discharge (2) l: RMSE = 0.0000, MAE = 0.0000, R² = 1.0000
# SSA 4 Schacht discharge (3) l: RMSE = 0.0000, MAE = 0.0000, R² = 1.0000
# SSA 4 Schacht ec (1) 120cm mS/cm: RMSE = 0.0579, MAE = 0.0554, R² = -2.3989
# SSA 4 Schacht ec (1) 30cm mS/cm: RMSE = 0.0047, MAE = 0.0036, R² = 0.9643
# SSA 4 Schacht ec (1) 75cm mS/cm: RMSE = 0.0090, MAE = 0.0055, R² = 0.9128
# SSA 4 Schacht ec (2) 120cm mS/cm: RMSE = 0.0085, MAE = 0.0080, R² = -0.5558
# SSA 4 Schacht ec (2) 30cm mS/cm: RMSE = 0.0121, MAE = 0.0103, R² = 0.9086
# SSA 4 Schacht ec (2) 75cm mS/cm: RMSE = 0.0064, MAE = 0.0063, R² = -286.1883
# SSA 4 Schacht ec (3) 120cm mS/cm: RMSE = 0.0116, MAE = 0.0099, R² = 0.9665
# SSA 4 Schacht ec (3) 30cm mS/cm: RMSE = 0.0037, MAE = 0.0028, R² = 0.7862
# SSA 4 Schacht ec (3) 75cm mS/cm: RMSE = 0.0064, MAE = 0.0043, R² = 0.8797
# SSA 4 Schacht temperature (1) 120cm degC: RMSE = 2.1621, MAE = 2.0884, R² = -0.0031
# SSA 4 Schacht temperature (1) 30cm degC: RMSE = 1.0630, MAE = 0.7291, R² = 0.9700
# SSA 4 Schacht temperature (1) 75cm degC: RMSE = 0.7831, MAE = 0.6642, R² = 0.9809
# SSA 4 Schacht temperature (2) 120cm degC: RMSE = 0.6926, MAE = 0.5631, R² = 0.9771
# SSA 4 Schacht temperature (2) 30cm degC: RMSE = 0.8915, MAE = 0.7673, R² = 0.9739
# SSA 4 Schacht temperature (2) 75cm degC: RMSE = 0.8363, MAE = 0.6858, R² = 0.9789
# SSA 4 Schacht temperature (3) 120cm degC: RMSE = 0.7804, MAE = 0.6219, R² = 0.9754
# SSA 4 Schacht temperature (3) 30cm degC: RMSE = 1.2187, MAE = 0.7960, R² = 0.9658
# SSA 4 Schacht temperature (3) 75cm degC: RMSE = 0.7977, MAE = 0.6502, R² = 0.9788
# SSA 4 Schacht vacuum 120cm kPa: RMSE = 4.8708, MAE = 3.6547, R² = 0.9272
# SSA 4 Schacht vacuum 140cm kPa: RMSE = 2.1550, MAE = 1.6256, R² = 0.9032
# SSA 4 Schacht vacuum 30cm kPa: RMSE = 6.0737, MAE = 4.4952, R² = 0.8589
# SSA 4 Schacht vacuum 75cm kPa: RMSE = 5.6411, MAE = 4.6986, R² = 0.7425
# URB Lysimeter discharge (1) l: RMSE = 0.0000, MAE = 0.0000, R² = 1.0000
# URB Lysimeter inside temperature degC: RMSE = 0.6801, MAE = 0.5638, R² = 0.9804
# URB Lysimeter inside tension kPa: RMSE = 0.6410, MAE = 0.6307, R² = -0.9917
# URB Lysimeter level cm: RMSE = 1.1635, MAE = 0.6757, R² = -0.2504
# URB Lysimeter level reference cm: RMSE = 0.0987, MAE = 0.0973, R² = -35.8341
# URB Lysimeter outside temperature degC: RMSE = 0.6758, MAE = 0.5955, R² = 0.9802
# URB Lysimeter outside tension kPa: RMSE = 1.1639, MAE = 0.8135, R² = 0.9661
# URB Lysimeter outside tension reference kPa: RMSE = 4.8726, MAE = 3.7488, R² = 0.7008
# URB Lysimeter percolation pump mV: RMSE = 1.6642, MAE = 1.3530, R² = 0.9596
# URB Lysimeter temperature control mV: RMSE = 1.5017, MAE = 1.2619, R² = 0.9535
# URB Lysimeter vacuum kPa: RMSE = 0.1822, MAE = 0.1690, R² = -3.7099
# Weather Station UMP (1) %: RMSE = 0.8862, MAE = 0.6824, R² = 0.9635
# Weather Station UMP (1) ec mS/cm: RMSE = 0.0056, MAE = 0.0037, R² = 0.8939
# Weather Station UMP (1) temperature degC: RMSE = 0.5911, MAE = 0.4636, R² = 0.9751
# Weather Station air pressure hPa: RMSE = 1.2660, MAE = 0.7635, R² = 0.9509
# Weather Station air temperature degC: RMSE = 1.6321, MAE = 1.2822, R² = 0.9639
# Weather Station battery V: RMSE = 0.1885, MAE = 0.1378, R² = 0.8815
# Weather Station humidity %: RMSE = 3.8959, MAE = 2.6831, R² = 0.9593
# Weather Station precipitation mm: RMSE = 0.0000, MAE = 0.0000, R² = 1.0000
# Weather Station radiation W/qm: RMSE = 40.5983, MAE = 25.0964, R² = 0.7024
# Weather Station temperature (5+) degC: RMSE = 1.8928, MAE = 1.3154, R² = 0.9536
# Weather Station wind direction deg: RMSE = 77.1859, MAE = 60.0085, R² = 0.3654
# Weather Station wind speed m/s: RMSE = 0.6057, MAE = 0.4448, R² = 0.7132

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
from tqdm import tqdm

# Train one Random Forest model per target
models_random_forest = {}
for col in tqdm(Y_train.columns, desc="Training Random Forest models"):
    var = Y_train[col].var()
    if var <= 100:
        params = {'n_estimators': 100, 'max_depth': 7}
    elif var >= 100 and var < 500:
        params = {'n_estimators': 175, 'max_depth': 12}
    else:
        params = {'n_estimators': 500, 'max_depth': 25}

    model_random_forest = RandomForestRegressor(
        n_estimators=params['n_estimators'],
        max_depth=params['max_depth'],
        n_jobs=-1,
        random_state=42,
        
    )
    model_random_forest.fit(X_train, Y_train[col])
    models_random_forest[col] = model_random_forest

# Predict all targets
Y_pred = pd.DataFrame(
    {col: models_random_forest[col].predict(X_test) for col in Y_train.columns},
    index=Y_test.index
)

print("Predictions shape:", Y_pred.shape)

# Calculate RMSE for each target
rmse_scores = {col: np.sqrt(root_mean_squared_error(Y_test[col], Y_pred[col])) for col in Y_test.columns}

# Display RMSE
for col, score in rmse_scores.items():
    print(f"{col}: RMSE = {score:.4f}")
# Out:
# Training Random Forest models: 100%|██████████| 75/75 [42:48<00:00, 34.25s/it]
# Predictions shape: (16255, 75)
# SSA 3 Lysimeter UMP 120cm %: RMSE = 1.2822
# SSA 3 Lysimeter UMP 30cm %: RMSE = 0.8500
# SSA 3 Lysimeter UMP 75cm %: RMSE = 0.6965
# SSA 3 Lysimeter battery V: RMSE = 0.3052
# SSA 3 Lysimeter ec 120cm mS/cm: RMSE = 0.0673
# SSA 3 Lysimeter ec 30cm mS/cm: RMSE = 0.0696
# SSA 3 Lysimeter ec 75cm mS/cm: RMSE = 0.0693
# SSA 3 Lysimeter scale (1) kg: RMSE = 4.9007
# SSA 3 Lysimeter temperature 120cm degC: RMSE = 0.2563
# SSA 3 Lysimeter temperature 30cm degC: RMSE = 0.3346
# SSA 3 Lysimeter temperature 75cm degC: RMSE = 0.3684
# SSA 3 Lysimeter tension 120cm kPa: RMSE = 0.2582
# SSA 3 Lysimeter tension 30cm kPa: RMSE = 0.5815
# SSA 3 Lysimeter tension 75cm kPa: RMSE = 0.3731
# SSA 3 Lysimeter vacuum 120cm kPa: RMSE = 0.4181
# SSA 3 Lysimeter vacuum 30cm kPa: RMSE = 0.4598
# SSA 3 Lysimeter vacuum 75cm kPa: RMSE = 0.8429
# SSA 4 Schacht UMP (1) 120cm %: RMSE = 3.5039
# SSA 4 Schacht UMP (1) 30cm %: RMSE = 0.7490
# SSA 4 Schacht UMP (1) 75cm %: RMSE = 0.7596
# SSA 4 Schacht UMP (2) 120cm %: RMSE = 2.5982
# SSA 4 Schacht UMP (2) 30cm %: RMSE = 0.7501
# SSA 4 Schacht UMP (2) 75cm %: RMSE = 1.6002
# SSA 4 Schacht UMP (3) 120cm %: RMSE = 2.5962
# SSA 4 Schacht UMP (3) 30cm %: RMSE = 1.1153
# SSA 4 Schacht UMP (3) 75cm %: RMSE = 0.8264
# SSA 4 Schacht battery V: RMSE = 0.3583
# SSA 4 Schacht discharge (1) l: RMSE = 0.0000
# SSA 4 Schacht discharge (2) l: RMSE = 0.0000
# SSA 4 Schacht discharge (3) l: RMSE = 0.0000
# SSA 4 Schacht ec (1) 120cm mS/cm: RMSE = 0.2593
# SSA 4 Schacht ec (1) 30cm mS/cm: RMSE = 0.0819
# SSA 4 Schacht ec (1) 75cm mS/cm: RMSE = 0.0926
# SSA 4 Schacht ec (2) 120cm mS/cm: RMSE = 0.0556
# SSA 4 Schacht ec (2) 30cm mS/cm: RMSE = 0.1716
# SSA 4 Schacht ec (2) 75cm mS/cm: RMSE = 0.1115
# SSA 4 Schacht ec (3) 120cm mS/cm: RMSE = 0.1006
# SSA 4 Schacht ec (3) 30cm mS/cm: RMSE = 0.0623
# SSA 4 Schacht ec (3) 75cm mS/cm: RMSE = 0.1091
# SSA 4 Schacht temperature (1) 120cm degC: RMSE = 1.3621
# SSA 4 Schacht temperature (1) 30cm degC: RMSE = 0.8247
# SSA 4 Schacht temperature (1) 75cm degC: RMSE = 0.9210
# SSA 4 Schacht temperature (2) 120cm degC: RMSE = 0.5700
# SSA 4 Schacht temperature (2) 30cm degC: RMSE = 0.5957
# SSA 4 Schacht temperature (2) 75cm degC: RMSE = 0.5707
# SSA 4 Schacht temperature (3) 120cm degC: RMSE = 0.7596
# SSA 4 Schacht temperature (3) 30cm degC: RMSE = 0.9036
# SSA 4 Schacht temperature (3) 75cm degC: RMSE = 0.6023
# SSA 4 Schacht vacuum 120cm kPa: RMSE = 2.5967
# SSA 4 Schacht vacuum 140cm kPa: RMSE = 1.4097
# SSA 4 Schacht vacuum 30cm kPa: RMSE = 2.6615
# SSA 4 Schacht vacuum 75cm kPa: RMSE = 2.5066
# URB Lysimeter discharge (1) l: RMSE = 0.0000
# URB Lysimeter inside temperature degC: RMSE = 0.3650
# URB Lysimeter inside tension kPa: RMSE = 0.2259
# URB Lysimeter level cm: RMSE = 2.1284
# URB Lysimeter level reference cm: RMSE = 0.7376
# URB Lysimeter outside temperature degC: RMSE = 0.2197
# URB Lysimeter outside tension kPa: RMSE = 1.8229
# URB Lysimeter outside tension reference kPa: RMSE = 2.6107
# URB Lysimeter percolation pump mV: RMSE = 1.5611
# URB Lysimeter temperature control mV: RMSE = 1.2579
# URB Lysimeter vacuum kPa: RMSE = 1.5777
# Weather Station UMP (1) %: RMSE = 0.9515
# Weather Station UMP (1) ec mS/cm: RMSE = 0.0799
# Weather Station UMP (1) temperature degC: RMSE = 0.7186
# Weather Station air pressure hPa: RMSE = 1.0860
# Weather Station air temperature degC: RMSE = 1.0810
# Weather Station battery V: RMSE = 0.4262
# Weather Station humidity %: RMSE = 2.0929
# Weather Station precipitation mm: RMSE = 0.0000
# Weather Station radiation W/qm: RMSE = 6.6413
# Weather Station temperature (5+) degC: RMSE = 1.2575
# Weather Station wind direction deg: RMSE = 9.0547
# Weather Station wind speed m/s: RMSE = 0.7807

# %%
import matplotlib.pyplot as plt

col = 'SSA 3 Lysimeter UMP 120cm %'

plt.figure(figsize=(8,6))
plt.scatter(Y_test.index, Y_test[col], color='blue', alpha=0.5, label='Actual')
plt.scatter(Y_test.index, Y_pred[col], color='orange', alpha=0.5, label='Predicted')

plt.xlabel('Index')
plt.ylabel(col)
plt.title(f'{col} Prediction vs Actual')
plt.legend()
plt.show()

# %%
rmse_scores = {col: np.sqrt(root_mean_squared_error(Y_test[col], Y_pred[col])) for col in Y_test.columns}

# Sort RMSE scores descending
rmse_sorted = sorted(rmse_scores.items(), key=lambda x: x[1], reverse=True)

# Write to txt file
output_path = "../random_forest_rmse.txt"
with open(output_path, "w") as f:
    f.write("Random Forest RMSE:\n\n")
    for col, score in rmse_sorted:
        f.write(f"{col}: RMSE = {score:.4f}\n")

# %%
import os
import joblib

#Create folder if not exists
os.makedirs('../models/removed_outliers_traditional_ml/random_forest', exist_ok=True)
# Save each model separately
for col, model in models_random_forest.items():
    filename = f"../models/removed_outliers_traditional_ml/random_forest/{col.replace('/', '_').replace(' ', '_')}.pkl"
    joblib.dump(model, filename)

print("All models saved successfully.")
# Out:
# All models saved successfully.

# %%
# RMSE
for col, score in rmse_scores.items():
    print(f"{col}: RMSE = {score:.4f}")

xgbboost_rmse_scores = {col: np.sqrt(root_mean_squared_error(Y_test[col], Y_pred[col])) for col in Y_test.columns}
# Sort RMSE scores descending
xgbboost_rmse_sorted = sorted(xgbboost_rmse_scores.items(), key=lambda x: x[1], reverse=True)
# Write to txt file
output_path = "../lightgbm_rmse.txt"
with open(output_path, "w") as f:
    f.write("lightgbm RMSE:\n\n")
    f.write("Sensor\t\t\t\t\tRMSE\t\tMAE\t\tR2\n")
    f.write("-" * 60 + "\n")
    for sensor, vals in metrics.items():
        f.write(f"{sensor:<35} {vals['RMSE']:<10.4f} {vals['MAE']:<10.4f} {vals['R2']:<10.4f}\n")
# Out:
# SSA 3 Lysimeter UMP 120cm %: RMSE = 1.2822
# SSA 3 Lysimeter UMP 30cm %: RMSE = 0.8500
# SSA 3 Lysimeter UMP 75cm %: RMSE = 0.6965
# SSA 3 Lysimeter battery V: RMSE = 0.3052
# SSA 3 Lysimeter ec 120cm mS/cm: RMSE = 0.0673
# SSA 3 Lysimeter ec 30cm mS/cm: RMSE = 0.0696
# SSA 3 Lysimeter ec 75cm mS/cm: RMSE = 0.0693
# SSA 3 Lysimeter scale (1) kg: RMSE = 4.9007
# SSA 3 Lysimeter temperature 120cm degC: RMSE = 0.2563
# SSA 3 Lysimeter temperature 30cm degC: RMSE = 0.3346
# SSA 3 Lysimeter temperature 75cm degC: RMSE = 0.3684
# SSA 3 Lysimeter tension 120cm kPa: RMSE = 0.2582
# SSA 3 Lysimeter tension 30cm kPa: RMSE = 0.5815
# SSA 3 Lysimeter tension 75cm kPa: RMSE = 0.3731
# SSA 3 Lysimeter vacuum 120cm kPa: RMSE = 0.4181
# SSA 3 Lysimeter vacuum 30cm kPa: RMSE = 0.4598
# SSA 3 Lysimeter vacuum 75cm kPa: RMSE = 0.8429
# SSA 4 Schacht UMP (1) 120cm %: RMSE = 3.5039
# SSA 4 Schacht UMP (1) 30cm %: RMSE = 0.7490
# SSA 4 Schacht UMP (1) 75cm %: RMSE = 0.7596
# SSA 4 Schacht UMP (2) 120cm %: RMSE = 2.5982
# SSA 4 Schacht UMP (2) 30cm %: RMSE = 0.7501
# SSA 4 Schacht UMP (2) 75cm %: RMSE = 1.6002
# SSA 4 Schacht UMP (3) 120cm %: RMSE = 2.5962
# SSA 4 Schacht UMP (3) 30cm %: RMSE = 1.1153
# SSA 4 Schacht UMP (3) 75cm %: RMSE = 0.8264
# SSA 4 Schacht battery V: RMSE = 0.3583
# SSA 4 Schacht discharge (1) l: RMSE = 0.0000
# SSA 4 Schacht discharge (2) l: RMSE = 0.0000
# SSA 4 Schacht discharge (3) l: RMSE = 0.0000
# SSA 4 Schacht ec (1) 120cm mS/cm: RMSE = 0.2593
# SSA 4 Schacht ec (1) 30cm mS/cm: RMSE = 0.0819
# SSA 4 Schacht ec (1) 75cm mS/cm: RMSE = 0.0926
# SSA 4 Schacht ec (2) 120cm mS/cm: RMSE = 0.0556
# SSA 4 Schacht ec (2) 30cm mS/cm: RMSE = 0.1716
# SSA 4 Schacht ec (2) 75cm mS/cm: RMSE = 0.1115
# SSA 4 Schacht ec (3) 120cm mS/cm: RMSE = 0.1006
# SSA 4 Schacht ec (3) 30cm mS/cm: RMSE = 0.0623
# SSA 4 Schacht ec (3) 75cm mS/cm: RMSE = 0.1091
# SSA 4 Schacht temperature (1) 120cm degC: RMSE = 1.3621
# SSA 4 Schacht temperature (1) 30cm degC: RMSE = 0.8247
# SSA 4 Schacht temperature (1) 75cm degC: RMSE = 0.9210
# SSA 4 Schacht temperature (2) 120cm degC: RMSE = 0.5700
# SSA 4 Schacht temperature (2) 30cm degC: RMSE = 0.5957
# SSA 4 Schacht temperature (2) 75cm degC: RMSE = 0.5707
# SSA 4 Schacht temperature (3) 120cm degC: RMSE = 0.7596
# SSA 4 Schacht temperature (3) 30cm degC: RMSE = 0.9036
# SSA 4 Schacht temperature (3) 75cm degC: RMSE = 0.6023
# SSA 4 Schacht vacuum 120cm kPa: RMSE = 2.5967
# SSA 4 Schacht vacuum 140cm kPa: RMSE = 1.4097
# SSA 4 Schacht vacuum 30cm kPa: RMSE = 2.6615
# SSA 4 Schacht vacuum 75cm kPa: RMSE = 2.5066
# URB Lysimeter discharge (1) l: RMSE = 0.0000
# URB Lysimeter inside temperature degC: RMSE = 0.3650
# URB Lysimeter inside tension kPa: RMSE = 0.2259
# URB Lysimeter level cm: RMSE = 2.1284
# URB Lysimeter level reference cm: RMSE = 0.7376
# URB Lysimeter outside temperature degC: RMSE = 0.2197
# URB Lysimeter outside tension kPa: RMSE = 1.8229
# URB Lysimeter outside tension reference kPa: RMSE = 2.6107
# URB Lysimeter percolation pump mV: RMSE = 1.5611
# URB Lysimeter temperature control mV: RMSE = 1.2579
# URB Lysimeter vacuum kPa: RMSE = 1.5777
# Weather Station UMP (1) %: RMSE = 0.9515
# Weather Station UMP (1) ec mS/cm: RMSE = 0.0799
# Weather Station UMP (1) temperature degC: RMSE = 0.7186
# Weather Station air pressure hPa: RMSE = 1.0860
# Weather Station air temperature degC: RMSE = 1.0810
# Weather Station battery V: RMSE = 0.4262
# Weather Station humidity %: RMSE = 2.0929
# Weather Station precipitation mm: RMSE = 0.0000
# Weather Station radiation W/qm: RMSE = 6.6413
# Weather Station temperature (5+) degC: RMSE = 1.2575
# Weather Station wind direction deg: RMSE = 9.0547
# Weather Station wind speed m/s: RMSE = 0.7807

# %%
os.makedirs('../models/removed_outliers_traditional_ml/lightgbm', exist_ok=True)


for col, model in models.items():
    safe_name = col.replace('/', '_').replace(' ', '_').replace('(', '').replace(')', '')
    path = f"../models/removed_outliers_traditional_ml/lightgbm/{safe_name}.pkl"
    joblib.dump(model, path)

print("All LightGBM models saved successfully.")
# Out:
# All LightGBM models saved successfully.
