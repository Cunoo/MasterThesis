# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame([
    {"RMSE": 3.7011, "MAE": 2.0632, "R2": 0.8721, "Model": "GRU"},
    {"RMSE": 5.2255, "MAE": 3.3874, "R2": 0.7953, "Model": "Attention"},
    {"RMSE": 3.9334, "MAE": 2.1980, "R2": 0.8651, "Model": "GRU+Attention"}
])
import numpy as np
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df))

plt.scatter(x_random, df['R2'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df['Model']):
    plt.annotate(model, (x_random[i], df['R2'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('R²')
plt.title('Comparation of models: R²')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('scatter_r2.png', dpi=150)
plt.show()

# %%
df_columns_ss4_sacht_120 = pd.DataFrame([
    {"RMSE": 0.0204, "MAE": 0.0105, "R2": 0.8856, "Model": "GRU", "column": "SSA 4 Schacht ec (1) 120cm mS/cm (1)"},
    {"RMSE": 0.0062, "MAE": 0.0041, "R2": 0.9893, "Model": "Attention", "column": "SSA 4 Schacht ec (1) 120cm mS/cm (1)"},
    {"RMSE":  0.0281, "MAE": 0.0139, "R2": 0.7822, "Model": "GRU+Attention", "column": "SSA 4 Schacht ec (1) 120cm mS/cm (1)"}
])

df_columns_ss4_sacht_30 = pd.DataFrame([
    {"RMSE": 0.0070, "MAE": 0.0045, "R2": 0.9321, "Model": "GRU", "column": "SSA 4 Schacht ec (1) 30cm mS/cm (1)"},
    {"RMSE": 0.0046, "MAE": 0.0041, "R2": 0.9893, "Model": "Attention", "column": "SSA 4 Schacht ec (1) 30cm mS/cm (1)"},
    {"RMSE":  0.0061, "MAE": 0.0040, "R2": 0.9483, "Model": "GRU+Attention", "column": "SSA 4 Schacht ec (1) 30cm mS/cm (1)"}
])


df_columns_ss4_sacht_75 = pd.DataFrame([
    {"RMSE": 0.0057, "MAE": 0.0035, "R2": 0.9401, "Model": "GRU", "column": "SSA 4 Schacht ec (1) 75cm mS/cm (1)"},
    {"RMSE": 0.0035, "MAE": 0.0023, "R2": 0.9775, "Model": "Attention", "column": "SSA 4 Schacht ec (1) 75cm mS/cm (1)"},
    {"RMSE":  0.0055, "MAE": 0.0033, "R2": 0.9447, "Model": "GRU+Attention", "column": "SSA 4 Schacht ec (1) 75cm mS/cm (1)"}
])

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_120))

plt.scatter(x_random, df_columns_ss4_sacht_120['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_120['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_120['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht ec (1) 120cm mS/cm (1)')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_ec_(1)_120cm)mScm_(1)_scatter_mae.png', dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_30))

plt.scatter(x_random, df_columns_ss4_sacht_30['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_30['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_30['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht ec (1) 30cm mS/cm (1)')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_ec_(1)_30cm)mScm_(1)_scatter_mae.png', dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_75))

plt.scatter(x_random, df_columns_ss4_sacht_75['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_75['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_75['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht ec (1) 30cm mS/cm (1)')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_ec_(1)_75cm)mScm_(1)_scatter_mae.png', dpi=150)
plt.show()

# %%
df_columns_ss4_sacht_120 = pd.DataFrame([
    {"RMSE": 0.9742, "MAE": 4.1352, "R2": 0.7360, "Model": "GRU", "column": "Schacht UMP (1) 120cm %"},
    {"RMSE": 2.3093, "MAE": 1.3097, "R2": 0.9825, "Model": "Attention", "column": "Schacht UMP (1) 120cm %"},
    {"RMSE":  10.3961, "MAE": 4.7515, "R2": 0.6457, "Model": "GRU+Attention", "column": "Schacht UMP (1) 120cm %"}
])

df_columns_ss4_sacht_30 = pd.DataFrame([
    {"RMSE": 0.6831, "MAE": 0.3420, "R2": 0.9779, "Model": "GRU", "column": "SSA 4 Schacht UMP (1) 30cm %"},
    {"RMSE": 0.6794, "MAE": 0.3581, "R2": 0.9782, "Model": "Attention", "column": "SSA 4 Schacht UMP (1) 30cm %"},
    {"RMSE":  0.8766, "MAE": 0.4296, "R2": 0.9637, "Model": "GRU+Attention", "column": "SSA 4 Schacht UMP (1) 30cm %"}
])


df_columns_ss4_sacht_75 = pd.DataFrame([
    {"RMSE": 1.7843, "MAE": 0.8107, "R2": 0.9307, "Model": "GRU", "column": "SSA 4 Schacht UMP (1) 75cm %"},
    {"RMSE": 0.6115, "MAE": 0.3859, "R2": 0.9919, "Model": "Attention", "column": "SSA 4 Schacht UMP (1) 75cm %"},
    {"RMSE":  1.7503, "MAE": 0.7963, "R2": 0.9333, "Model": "GRU+Attention", "column": "SSA 4 Schacht UMP (1) 75cm %"}
])

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_120))

plt.scatter(x_random, df_columns_ss4_sacht_120['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_120['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_120['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht UMP (1) 120cm %')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_UMP_(1)_120cm_%_scatter_mae.png', dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_30))

plt.scatter(x_random, df_columns_ss4_sacht_30['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_30['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_30['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht UMP (1) 30cm %')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_UMP_(1)_30cm_%_scatter_mae.png', dpi=150)
plt.show()

# %%
plt.figure(figsize=(8, 5))
np.random.seed(42)
x_random = np.random.rand(len(df_columns_ss4_sacht_75))

plt.scatter(x_random, df_columns_ss4_sacht_75['MAE'], s=200, c=['#1f77b4', '#ff7f0e', '#2ca02c'])
for i, model in enumerate(df_columns_ss4_sacht_75['Model']):
    plt.annotate(model, (x_random[i], df_columns_ss4_sacht_75['MAE'][i]), xytext=(0, 10), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

plt.ylabel('MAE')
plt.title('Comparation of models: MAE on column SSA 4 Schacht UMP (1) 75cm %')
plt.xticks([])
plt.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('SSA_4_Schacht_UMP_(1)_75cm_%_scatter_mae.png', dpi=150)
plt.show()
