# %%
import pandas as pd

df = pd.read_parquet("../../data/pivot_data_imputed.parquet")
df.to_excel("../../data/pivot_data_imputed.xlsx")

# %%
import pandas as pd

df = pd.read_parquet("../../data/pivot_data_imputed.parquet")
df.head()
# Out:
# MeasurementName      SSA 3 Lysimeter UMP 120cm %  SSA 3 Lysimeter UMP 30cm %  \
# MeasureDate
# 2013-07-01 00:00:00                    32.709999                       25.17
# 2013-07-01 00:14:00                    32.730000                       25.17
# 2013-07-01 00:30:00                    32.720001                       25.17
# 2013-07-01 00:45:00                    32.720001                       25.17
# 2013-07-01 00:59:00                    32.619999                       25.17
#
# MeasurementName      SSA 3 Lysimeter UMP 75cm %  SSA 3 Lysimeter battery V  \
# MeasureDate
# 2013-07-01 00:00:00                   33.700001                      12.72
# 2013-07-01 00:14:00                   33.689999                      12.71
# 2013-07-01 00:30:00                   33.689999                      12.71
# 2013-07-01 00:45:00                   33.689999                      12.70
# 2013-07-01 00:59:00                   33.689999                      12.69
#
# ...
